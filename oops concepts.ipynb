# %%
#class
class object:
    x=7
    y=8
op=object()
op.x
# Out:
# 7

# %%
class object:
    def add(self,a,b):
        return a+b
    
op=object()
k=op.add(7,8)
print(k)
# Out:
# 15

# %%
class object:
    def sub(self):
        a=9
        b=8
        return a-b
op=object()
k=op.sub()
print(k)
# Out:
# 1

# %%
#Inheritense
university
college
department
